# %%
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
import numpy as np
import pystan
from keras import datasets
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4150f0b2-d727-44c5-b080-f40242104aa6">Loading BokehJS ...</span>
#     </div>

# %%
(X_train, y_train), (X_test, y_test) = datasets.mnist.load_data()

X_train = X_train.reshape(-1, 28**2)
X_test = X_test.reshape(-1, 28**2)

X_train = X_train/128
X_test = X_test/128

y_train_oh = np.eye(10)[y_train]
y_test_oh = np.eye(10)[y_test]

X_train = X_train.astype('float32')
y_train_oh = y_train_oh.astype('float32')
X_test = X_test.astype('float32')
y_test_oh = y_test_oh.astype('float32')

N, DIN = X_train.shape
DOUT = 10

# %%
code = """
data {
    int K;
    int N;
    int D;
    int y[N];
    vector[D] x[N];
}
parameters {
    matrix[K, D] beta;
}
model {
    for (k in 1:K)
        beta[k] ~ normal(0, 5);
    for (n in 1:N)
        y[n] ~ categorical_logit(beta * x[n]);
}
"""
model = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_da7467fd508e42397bebd53bbea4fd4c NOW.

# %%
y_train = y_train.astype('int32')
N = 10
K = 3
mask = y_train <= 3

data = {
    'N': N,
    'K': ,
    'D': X_train.shape[1],
    'y': y_train[:N].astype('int32'),
    'x': X_train[:N],
}
fit = model.sampling(data=data)
# Out:
# Process ForkPoolWorker-7:
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
# Process ForkPoolWorker-6:
# Traceback (most recent call last):
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/queues.py", line 342, in get
#     with self._rlock:
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/roliveira/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9fc347cb9a0c> in <module>()
#       7     'x': X_train[:N],
#       8 }
# ----> 9 fit = model.sampling(data=data)
#
# /Users/roliveira/anaconda3/lib/python3.6/site-packages/pystan/model.py in sampling(self, data, pars, chains, iter, warmup, thin, seed, init, sample_file, diagnostic_file, verbose, algorithm, control, n_jobs, **kwargs)
#     718         call_sampler_args = izip(itertools.repeat(data), args_list, itertools.repeat(pars))
#     719         call_sampler_star = self.module._call_sampler_star
# --> 720         ret_and_samples = _map_parallel(call_sampler_star, call_sampler_args, n_jobs)
#     721         samples = [smpl for _, smpl in ret_and_samples]
#     722
#
# /Users/roliveira/anaconda3/lib/python3.6/site-packages/pystan/model.py in _map_parallel(function, args, n_jobs)
#      78             n_jobs = None
#      79         pool = multiprocessing.Pool(processes=n_jobs)
# ---> 80         map_result = pool.map(function, args)
#      81         pool.close()
#      82         pool.join()
#
# /Users/roliveira/anaconda3/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
#     262     def starmap(self, func, iterable, chunksize=None):
#
# /Users/roliveira/anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /Users/roliveira/anaconda3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /Users/roliveira/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /Users/roliveira/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
